# %%
import pandas
df = pandas.read_csv('/Users/emorales/Downloads/actividad-clase-2.csv', index_col='taxi_id', parse_dates=['payment_type'])
print(df)
type(file)
csvreader = csv.reader(file)
header = {
  "taxi_id": "",
  "trip_total": "",
  "payment_type": "Credit Card",}
print(header)
# Out:
#                                                                                   unique_key  \
# taxi_id
# 0a93e246fb9b99a3be61ca72d6e9ca02ca57fd26fa38ac4...  00072781e643fd94d19bb28ce130604e4f2db3ec
# ec73aeaa166a9fabcd546bd176e75ee589e58653db8b0c7...  00073f4c6c9b4c237b1e936d17bb711dfa0b6a97
# 51620bbd9c2f977b8abcf5537e65f0fa24af77d00fb3c20...  0008a6d1250f6c23862d13b9d3fe947159652e24
# 1626f97f0f9d0b836ff89cc85c91115b3450ea6e6db6b82...  000fa41b1c692b6cc2f9b9b5e3765c08f64d28be
# 888ae68d70813efa2665c4293ed0a5b5f82cdd3ed4b7041...  00105ef7f0b8d6c2dfce7b0a454376440100c787
# ...                                                                                      ...
# 92195ba6d79380aa9da1f2db98ac05a3eff859c4151f242...  07e89a84514540012a8f7c8eda46d1fee1384aea
# 10a3a3db038a616cf1e784ef0c6bb9dd6e3d2cfb94f50e9...  07ea35621f9ef5dfb6e8ba815ec9095de68e7d3f
# 712d5ce61776db6be84e481833c75cae321ee8dd1e6b93b...  07ecdf5e05aeb4b9975c9745f04bdd131a9d47eb
# ...
